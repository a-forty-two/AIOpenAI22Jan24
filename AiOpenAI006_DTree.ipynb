# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/AIOpenAI22Jan24/blob/main/AiOpenAI006_DTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/AIOpenAI22Jan24/main/data.csv', header=0)
df = data.iloc[:, [1,2,5,6,9]]
df.head(100)
# Out:
#    diagnosis  radius_mean  area_mean  smoothness_mean  concave points_mean
# 0          M       17.990     1001.0          0.11840             0.147100
# 1          M       20.570     1326.0          0.08474             0.070170
# 2          M       19.690     1203.0          0.10960             0.127900
# 3          M       11.420      386.1          0.14250             0.105200
# 4          M       20.290     1297.0          0.10030             0.104300
# ..       ...          ...        ...              ...                  ...
# 95         M       20.260     1264.0          0.09078             0.086830
# 96         B       12.180      451.1          0.10450             0.029410
# 97         B        9.787      294.5          0.10240             0.007937
# 98         B       11.600      412.6          0.08983             0.033500
# 99         M       14.420      642.5          0.09752             0.058390
#
# [100 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['radius_mean'].plot(kind='hist', bins=20, title='radius_mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['area_mean'].plot(kind='hist', bins=20, title='area_mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['smoothness_mean'].plot(kind='hist', bins=20, title='smoothness_mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['concave points_mean'].plot(kind='hist', bins=20, title='concave points_mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_15.groupby('diagnosis').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='radius_mean', y='area_mean', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17.plot(kind='scatter', x='area_mean', y='smoothness_mean', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='smoothness_mean', y='concave points_mean', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19['radius_mean'].plot(kind='line', figsize=(8, 4), title='radius_mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['area_mean'].plot(kind='line', figsize=(8, 4), title='area_mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['smoothness_mean'].plot(kind='line', figsize=(8, 4), title='smoothness_mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['concave points_mean'].plot(kind='line', figsize=(8, 4), title='concave points_mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['diagnosis'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='radius_mean', y='diagnosis', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['diagnosis'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='area_mean', y='diagnosis', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['diagnosis'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='smoothness_mean', y='diagnosis', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['diagnosis'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='concave points_mean', y='diagnosis', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
y = df.pop('diagnosis') # REMOVE the feature from df and put into y
x = df
# y = f(x) -> equation for DTree
from sklearn.model_selection import train_test_split
xtrain,xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Decision Tree, Random Forest -> work on relative comparison -> NORMALIZING or NOT normalizing
# may not cause any diff at all
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=5)
dtree_light =  DecisionTreeClassifier(max_depth=3)
dtree_deep =  DecisionTreeClassifier(max_depth=10)
dtree.fit(xtrain, ytrain)
dtree_light.fit(xtrain, ytrain)
dtree_deep.fit(xtrain, ytrain)
# WEIGHTS and BIASES, y = Weights * inputs + bias -> MACHINE LEARNING
# Decision TREE doesn't help with calculating the above!
# it helps finding thresholds within which features take decisions
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
pred1 = dtree.predict(xtest)
pred2 = dtree_light.predict(xtest)
pred3 = dtree_deep.predict(xtest)
from sklearn.metrics import accuracy_score
# COMPARING the TREES to each other, not to the actual answer (ytest)
score = accuracy_score(pred1, pred2)
print(score)
score = accuracy_score(pred1, pred3)
print(score)
score = accuracy_score(pred3, pred2)
print(score)
# ACCURACY_SCORE(a, b) = (len(any) - mismatches) / len(any)
# Out:
# 0.9385964912280702
# 0.9736842105263158
# 0.9649122807017544

# %%
# Out:
# array(['B', 'M', 'M', 'B', 'B'], dtype=object)

# %%
accuracy_score(pred1,ytest)
# Out:
# 0.9210526315789473

# %%
accuracy_score(pred2,ytest)
# Out:
# 0.8947368421052632

# %%
accuracy_score(pred3,ytest)
# Out:
# 0.9122807017543859

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,25))
a = plot_tree(dtree_deep, feature_names=x.columns, fontsize=10, filled=True, class_names=['M','B'])
plt.show()
# GINI and ENTROPY

# INDIVIDUAL TREE-> weak learning/guessing machine
# FORESTS or JUNGLE (Ensemble)-> create 100s of trees
#     Some trees will create majority decision
